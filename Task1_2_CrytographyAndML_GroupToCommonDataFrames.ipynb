# %%
'''
To user using this copy, main changes if user want to use this for a different file with different column
have to amend the column names accordingly in the python file

When run the .py file will prompt you for file name. (Filepath included)

'''
fn = input("What is your filename? : ") # dummydata_renamed_updated.xlsx"

import pandas as pd

dfADA = pd.read_excel(fn,converters ={'SFX':str, 'Corp CIN':str})
dfADA['Acc Number'] =dfADA['Acc Number'].str.strip()
dfADA['Acc Number'].tolist()
type(dfADA['Corp CIN'][1])
# Out:
# What is your filename? : dummydata_renamed_updated.xlsx
# str

# %%
'''
we filter by what the user wants to filter by, either by Corp CIN or ACC, if CIN, then we run the filter across the Corp CIN
'''
CINorAcc = input("Do you want to filter by 'Corp CIN' or 'ACC' Num? : ") # CIN or ACC
if CINorAcc == "ACC":
    accountNum = input("Please provide a list of account numbers separated by commas: ") #0001-003579-05-0,001-018760-01,001-003965-5
    #convert to list
    accountNum = accountNum.split(",")
    #To select rows whose column value is in the list
    dfADA = dfADA[dfADA['Acc Number'].isin(accountNum)]
    dfADA
elif CINorAcc=="Corp CIN":
    # To select rows whose column value is in list
    CorpCIN = input("Please provide a Corp CIN number: ") #1234567,1234568,1234569
    CorpCIN = CorpCIN.split(",")
    dfADA = dfADA[dfADA['Corp CIN'].isin(CorpCIN)]
else:
    print("Please enter a valid name")
dfADA
# Out:
# Do you want to filter by 'Corp CIN' or 'ACC' Num? : 1234567,1234568,1234569
# Please enter a valid name
#    Corp CIN        Acc Number Group    ind CIN SFX         Name
# 0   1234567      001-005162-8     A  S4695746A  00    Apple Lim
# 1   1234567      001-005162-8     A  S5868811B  00    Brave Lau
# 2   1234567      001-005162-8     A  S8377456C  00  Charles Tan
# 3   1234567      001-005162-8     A  S1478175K  00    Keith Kin
# 4   1234567  0001-003579-05-0     C  S7114220I  20      Ice Ice
# 5   1234567  0001-003579-05-0     C  S2349083k  20   Jelly Bean
# 6   1234567  0001-003579-05-0     D  S1478175K  00    Keith Kin
# 7   1234567  0001-003579-05-0     D  S1184805L  00   Lim Ah How
# 8   1234567  0001-003579-05-0     A  S4695746A  00    Apple Lim
# 9   1234567  0003-001933-01-3     A  S4695746A  00    Apple Lim
# 10  1234567  0003-002011-02-1     A  S4695746A  00    Apple Lim
# 11  1234567  0003-018997-03-6     A  S4695746A  00    Apple Lim
# 12  1234567  0003-020908-01-6     A  S4695746A  00    Apple Lim
# 13  1234567  0118-000200-01-8     A  S4695746A  00    Apple Lim
# 14  1234567     001-018760-01     A  S4695746A  00    Apple Lim
# 15  1234567     001-018760-01     A  S5868811B  00    Brave Lau
# 16  1234568      001-026485-0     A  S4695746A  00    Apple Lim
# 17  1234568      001-026485-0     A  S5868811B  00    Brave Lau
# 18  1234568      001-026485-0     A  S8377456C  00  Charles Tan
# 19  1234569      001-033965-5     B  S4695746A  00    Apple Lim
# 20  1234569      001-033965-5     B  S5868811B  00    Brave Lau
# 21  1234567      001-033965-5     A  S8377456C  00  Charles Tan

# %%
'''
Because i want to make Acc Number the key later, we put it in the first column

'''
# change order of columns in a dataframe, 'Acc Number' put infront
dfAccNum = dfADA['Acc Number'].unique()
dfAccNum_list = dfAccNum.tolist()
print("List of account numbers unique : {}".format(dfAccNum_list))

# reorder the columns in the df before i do a join'_' on dfADA
new_order = [1,0,2,3,4,5]
dfADA = dfADA[dfADA.columns[new_order]]
print(dfADA.head())
# Out:
# List of account numbers unique : ['001-005162-8', '0001-003579-05-0', '0003-001933-01-3', '0003-002011-02-1', '0003-018997-03-6', '0003-020908-01-6', '0118-000200-01-8', '001-018760-01', '001-026485-0', '001-033965-5']
#          Acc Number Corp CIN Group    ind CIN SFX         Name
# 0      001-005162-8  1234567     A  S4695746A  00    Apple Lim
# 1      001-005162-8  1234567     A  S5868811B  00    Brave Lau
# 2      001-005162-8  1234567     A  S8377456C  00  Charles Tan
# 3      001-005162-8  1234567     A  S1478175K  00    Keith Kin
# 4  0001-003579-05-0  1234567     C  S7114220I  20      Ice Ice

# %%
# Join all the columns separated by '_'
dfADA_str = dfADA.astype(str)
dfADA_str['joined'] = dfADA_str.apply('_'.join, axis =1 )
dfADA_str.head()
# Out:
#          Acc Number Corp CIN Group    ind CIN SFX         Name  \
# 0      001-005162-8  1234567     A  S4695746A  00    Apple Lim
# 1      001-005162-8  1234567     A  S5868811B  00    Brave Lau
# 2      001-005162-8  1234567     A  S8377456C  00  Charles Tan
# 3      001-005162-8  1234567     A  S1478175K  00    Keith Kin
# 4  0001-003579-05-0  1234567     C  S7114220I  20      Ice Ice
#
#                                             joined
# 0    001-005162-8_1234567_A_S4695746A_00_Apple Lim
# 1    001-005162-8_1234567_A_S5868811B_00_Brave Lau
# 2  001-005162-8_1234567_A_S8377456C_00_Charles Tan
# 3    001-005162-8_1234567_A_S1478175K_00_Keith Kin
# 4  0001-003579-05-0_1234567_C_S7114220I_20_Ice Ice

# %%
'''
split back the 'Acc Number' because they key is only "joined" column, and does not need account number
'''
# Split away the Acc Number column as it will be "Key-like" for later use
split_list = []
for string in dfADA_str.joined:
    split_Acc = string.split("_",1)
    split_list.append(split_Acc)
    
split_list
# Out:
# [['001-005162-8', '1234567_A_S4695746A_00_Apple Lim'],
#  ['001-005162-8', '1234567_A_S5868811B_00_Brave Lau'],
#  ['001-005162-8', '1234567_A_S8377456C_00_Charles Tan'],
#  ['001-005162-8', '1234567_A_S1478175K_00_Keith Kin'],
#  ['0001-003579-05-0', '1234567_C_S7114220I_20_Ice Ice'],
#  ['0001-003579-05-0', '1234567_C_S2349083k_20_Jelly Bean'],
#  ['0001-003579-05-0', '1234567_D_S1478175K_00_Keith Kin'],
#  ['0001-003579-05-0', '1234567_D_S1184805L_00_Lim Ah How'],
#  ['0001-003579-05-0', '1234567_A_S4695746A_00_Apple Lim'],
#  ['0003-001933-01-3', '1234567_A_S4695746A_00_Apple Lim'],
#  ['0003-002011-02-1', '1234567_A_S4695746A_00_Apple Lim'],
#  ['0003-018997-03-6', '1234567_A_S4695746A_00_Apple Lim'],
#  ['0003-020908-01-6', '1234567_A_S4695746A_00_Apple Lim'],
#  ['0118-000200-01-8', '1234567_A_S4695746A_00_Apple Lim'],
#  ['001-018760-01', '1234567_A_S4695746A_00_Apple Lim'],
#  ['001-018760-01', '1234567_A_S5868811B_00_Brave Lau'],
#  ['001-026485-0', '1234568_A_S4695746A_00_Apple Lim'],
#  ['001-026485-0', '1234568_A_S5868811B_00_Brave Lau'],
#  ['001-026485-0', '1234568_A_S8377456C_00_Charles Tan'],
#  ['001-033965-5', '1234569_B_S4695746A_00_Apple Lim'],
#  ['001-033965-5', '1234569_B_S5868811B_00_Brave Lau'],
#  ['001-033965-5', '1234567_A_S8377456C_00_Charles Tan']]

# %%
# convert the list of list back to a pandas dataframe
import pandas as pd
df = pd.DataFrame(split_list, columns = ['Acc Num','joined'])
df.head()
# Out:
#             Acc Num                              joined
# 0      001-005162-8    1234567_A_S4695746A_00_Apple Lim
# 1      001-005162-8    1234567_A_S5868811B_00_Brave Lau
# 2      001-005162-8  1234567_A_S8377456C_00_Charles Tan
# 3      001-005162-8    1234567_A_S1478175K_00_Keith Kin
# 4  0001-003579-05-0      1234567_C_S7114220I_20_Ice Ice

# %%
'''
Sort each list (in each row by ascending order so when we join the Dataframe the long string of rows in dataframe is ordered)
The ultimate aim is a dataframe for each group of account numbers.
To compare if the dataframes are the same, need to append all the rows of each dataframe that belongs to each account number 
into one long string

In order for the strings to be correctly matched, we need to sort the rows first before join
'''
dfsort = df.sort_values('joined', ascending = False)

# %%
'''
for each account number, join all the individual credential columns for each account number
'''
#https://stackoverflow.com/questions/22219004/grouping-rows-in-list-in-pandas-groupby
dfgrouped = dfsort.groupby('Acc Num')['joined'].apply(list)
dfgrouped1 = pd.DataFrame(dfgrouped,columns = ['joined'])
print(dfgrouped1.head())
# Out:
#                                                              joined
# Acc Num
# 0001-003579-05-0  [1234567_D_S1478175K_00_Keith Kin, 1234567_D_S...
# 0003-001933-01-3                 [1234567_A_S4695746A_00_Apple Lim]
# 0003-002011-02-1                 [1234567_A_S4695746A_00_Apple Lim]
# 0003-018997-03-6                 [1234567_A_S4695746A_00_Apple Lim]
# 0003-020908-01-6                 [1234567_A_S4695746A_00_Apple Lim]

# %%
'''
To check if a dataframe is the same across a few accounts, we need to join (delimiter = '+') 
all the rows in the dataframe then check across
all the accounts
'''
appendlist= []
for item in dfgrouped:
    a = "+".join(item)
    appendlist.append(a)
print(type(appendlist))

dfgrouped1 = dfgrouped1.assign(joinedlistToAcc = appendlist)
dfgrouped1
# Out:
# <class 'list'>
#                                                              joined  \
# Acc Num
# 0001-003579-05-0  [1234567_D_S1478175K_00_Keith Kin, 1234567_D_S...
# 0003-001933-01-3                 [1234567_A_S4695746A_00_Apple Lim]
# 0003-002011-02-1                 [1234567_A_S4695746A_00_Apple Lim]
# 0003-018997-03-6                 [1234567_A_S4695746A_00_Apple Lim]
# 0003-020908-01-6                 [1234567_A_S4695746A_00_Apple Lim]
# 001-005162-8      [1234567_A_S8377456C_00_Charles Tan, 1234567_A...
# 001-018760-01     [1234567_A_S5868811B_00_Brave Lau, 1234567_A_S...
# 001-026485-0      [1234568_A_S8377456C_00_Charles Tan, 1234568_A...
# 001-033965-5      [1234569_B_S5868811B_00_Brave Lau, 1234569_B_S...
# 0118-000200-01-8                 [1234567_A_S4695746A_00_Apple Lim]
#
#                                                     joinedlistToAcc
# Acc Num
# 0001-003579-05-0  1234567_D_S1478175K_00_Keith Kin+1234567_D_S11...
# 0003-001933-01-3                   1234567_A_S4695746A_00_Apple Lim
# 0003-002011-02-1                   1234567_A_S4695746A_00_Apple Lim
# 0003-018997-03-6                   1234567_A_S4695746A_00_Apple Lim
# 0003-020908-01-6                   1234567_A_S4695746A_00_Apple Lim
# 001-005162-8      1234567_A_S8377456C_00_Charles Tan+1234567_A_S...
# 001-018760-01     1234567_A_S5868811B_00_Brave Lau+1234567_A_S46...
# 001-026485-0      1234568_A_S8377456C_00_Charles Tan+1234568_A_S...
# 001-033965-5      1234569_B_S5868811B_00_Brave Lau+1234569_B_S46...
# 0118-000200-01-8                   1234567_A_S4695746A_00_Apple Lim

# %%
'''
Make a duplicate of index column
'''
dfgrouped1['Acc'] = dfgrouped1.index
dfgrouped1

dfgrouped.index[9]
# Out:
# '0118-000200-01-8'

# %%
'''
Aggregate together the account numbers to each set of dataframe
'''  
dfgrouped2 = dfgrouped1.groupby('joinedlistToAcc')['Acc'].apply(list) # pandas series. Grouped by 'joinedlistToAcc'
dfgrouped3 = dfgrouped2.to_frame()
# make  'joinedlistToAcc' a duplicate since it is the index with no header name
dfgrouped3['joinedList_ToAcc'] = dfgrouped3.index

# %%
'''
Split 'joinedlist_ToAcc' back to each column
'''
person = []
for row in dfgrouped3.iterrows():
    sentence = row[0]
    sentence1 = sentence.split("+")
    person.append(sentence1)
print(person)
print("Check number of blocks = {}".format(len(person)))

# cast list back to the dataframe
dfgrouped3 = dfgrouped3.assign(individual= person)
dfgrouped3
# Out:
# [['1234567_A_S4695746A_00_Apple Lim'], ['1234567_A_S5868811B_00_Brave Lau', '1234567_A_S4695746A_00_Apple Lim'], ['1234567_A_S8377456C_00_Charles Tan', '1234567_A_S5868811B_00_Brave Lau', '1234567_A_S4695746A_00_Apple Lim', '1234567_A_S1478175K_00_Keith Kin'], ['1234567_D_S1478175K_00_Keith Kin', '1234567_D_S1184805L_00_Lim Ah How', '1234567_C_S7114220I_20_Ice Ice', '1234567_C_S2349083k_20_Jelly Bean', '1234567_A_S4695746A_00_Apple Lim'], ['1234568_A_S8377456C_00_Charles Tan', '1234568_A_S5868811B_00_Brave Lau', '1234568_A_S4695746A_00_Apple Lim'], ['1234569_B_S5868811B_00_Brave Lau', '1234569_B_S4695746A_00_Apple Lim', '1234567_A_S8377456C_00_Charles Tan']]
# Check number of blocks = 6
#                                                                                                   Acc  \
# joinedlistToAcc
# 1234567_A_S4695746A_00_Apple Lim                    [0003-001933-01-3, 0003-002011-02-1, 0003-0189...
# 1234567_A_S5868811B_00_Brave Lau+1234567_A_S469...                                    [001-018760-01]
# 1234567_A_S8377456C_00_Charles Tan+1234567_A_S5...                                     [001-005162-8]
# 1234567_D_S1478175K_00_Keith Kin+1234567_D_S118...                                 [0001-003579-05-0]
# 1234568_A_S8377456C_00_Charles Tan+1234568_A_S5...                                     [001-026485-0]
# 1234569_B_S5868811B_00_Brave Lau+1234569_B_S469...                                     [001-033965-5]
#
#                                                                                      joinedList_ToAcc  \
# joinedlistToAcc
# 1234567_A_S4695746A_00_Apple Lim                                     1234567_A_S4695746A_00_Apple Lim
# 1234567_A_S5868811B_00_Brave Lau+1234567_A_S469...  1234567_A_S5868811B_00_Brave Lau+1234567_A_S46...
# 1234567_A_S8377456C_00_Charles Tan+1234567_A_S5...  1234567_A_S8377456C_00_Charles Tan+1234567_A_S...
# 1234567_D_S1478175K_00_Keith Kin+1234567_D_S118...  1234567_D_S1478175K_00_Keith Kin+1234567_D_S11...
# 1234568_A_S8377456C_00_Charles Tan+1234568_A_S5...  1234568_A_S8377456C_00_Charles Tan+1234568_A_S...
# 1234569_B_S5868811B_00_Brave Lau+1234569_B_S469...  1234569_B_S5868811B_00_Brave Lau+1234569_B_S46...
#
#                                                                                            individual
# joinedlistToAcc
# 1234567_A_S4695746A_00_Apple Lim                                   [1234567_A_S4695746A_00_Apple Lim]
# 1234567_A_S5868811B_00_Brave Lau+1234567_A_S469...  [1234567_A_S5868811B_00_Brave Lau, 1234567_A_S...
# 1234567_A_S8377456C_00_Charles Tan+1234567_A_S5...  [1234567_A_S8377456C_00_Charles Tan, 1234567_A...
# 1234567_D_S1478175K_00_Keith Kin+1234567_D_S118...  [1234567_D_S1478175K_00_Keith Kin, 1234567_D_S...
# 1234568_A_S8377456C_00_Charles Tan+1234568_A_S5...  [1234568_A_S8377456C_00_Charles Tan, 1234568_A...
# 1234569_B_S5868811B_00_Brave Lau+1234569_B_S469...  [1234569_B_S5868811B_00_Brave Lau, 1234569_B_S...

# %%
'''
Drop unncecessary columns from pandas dataframe
'''
dfgrouped3.drop('joinedList_ToAcc',axis= 1 , inplace=True)
print(type(dfgrouped3))
dfgrouped3
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                                                                                   Acc  \
# joinedlistToAcc
# 1234567_A_S4695746A_00_Apple Lim                    [0003-001933-01-3, 0003-002011-02-1, 0003-0189...
# 1234567_A_S5868811B_00_Brave Lau+1234567_A_S469...                                    [001-018760-01]
# 1234567_A_S8377456C_00_Charles Tan+1234567_A_S5...                                     [001-005162-8]
# 1234567_D_S1478175K_00_Keith Kin+1234567_D_S118...                                 [0001-003579-05-0]
# 1234568_A_S8377456C_00_Charles Tan+1234568_A_S5...                                     [001-026485-0]
# 1234569_B_S5868811B_00_Brave Lau+1234569_B_S469...                                     [001-033965-5]
#
#                                                                                            individual
# joinedlistToAcc
# 1234567_A_S4695746A_00_Apple Lim                                   [1234567_A_S4695746A_00_Apple Lim]
# 1234567_A_S5868811B_00_Brave Lau+1234567_A_S469...  [1234567_A_S5868811B_00_Brave Lau, 1234567_A_S...
# 1234567_A_S8377456C_00_Charles Tan+1234567_A_S5...  [1234567_A_S8377456C_00_Charles Tan, 1234567_A...
# 1234567_D_S1478175K_00_Keith Kin+1234567_D_S118...  [1234567_D_S1478175K_00_Keith Kin, 1234567_D_S...
# 1234568_A_S8377456C_00_Charles Tan+1234568_A_S5...  [1234568_A_S8377456C_00_Charles Tan, 1234568_A...
# 1234569_B_S5868811B_00_Brave Lau+1234569_B_S469...  [1234569_B_S5868811B_00_Brave Lau, 1234569_B_S...

# %%
'''
Construct a new dataframe,actually because want to drop the index column and "Acc" column
'''
dfnew = pd.DataFrame(list(zip(dfgrouped3.Acc,dfgrouped3.individual)))
dfnew.columns = ['acc_num', 'listOfNames'] # rename fields
dfnew
# Out:
#                                              acc_num  \
# 0  [0003-001933-01-3, 0003-002011-02-1, 0003-0189...
# 1                                    [001-018760-01]
# 2                                     [001-005162-8]
# 3                                 [0001-003579-05-0]
# 4                                     [001-026485-0]
# 5                                     [001-033965-5]
#
#                                          listOfNames
# 0                 [1234567_A_S4695746A_00_Apple Lim]
# 1  [1234567_A_S5868811B_00_Brave Lau, 1234567_A_S...
# 2  [1234567_A_S8377456C_00_Charles Tan, 1234567_A...
# 3  [1234567_D_S1478175K_00_Keith Kin, 1234567_D_S...
# 4  [1234568_A_S8377456C_00_Charles Tan, 1234568_A...
# 5  [1234569_B_S5868811B_00_Brave Lau, 1234569_B_S...

# %%
'''
Construct new dataframe for each set of "acc_num", just like in the task requirement
choose set_num, to view the output
'''
def choose_frame(set_num):
    # print('df_set{}'.format(set_num))
    dfsep = pd.DataFrame(dfnew.iloc[set_num]).T
    return(dfsep)

# %%
'''
this func is to cast the columns to a df after splitting the listOfNames
'''
def my_function(row):
    # row is df
    # initialise a dataframe
    df = pd.DataFrame({'list_of_name': row['listOfNames']})
    new = df['list_of_name'].str.split("_", n=4 , expand = True)
    df['Corp CIN'] = new[0]
    df['Group'] = new[1]
    df['ind CIN'] = new[2]
    df['SFX'] = new[3]
    df['Name'] = new[4]
    df['account_no'] = [row['acc_num']]*df.shape[0] # repeat the col of acc_no
    return(df)

# %%
'''
apply the function created on your dataframe 'dfnew'

this is because for each row in dfnew , we want to extract the elements in the credentials of the 
individuals in "listOf"
'''
w = dfnew.apply(my_function, axis =1)
w[2]
# Out:
#                          list_of_name Corp CIN Group    ind CIN SFX  \
# 0  1234567_A_S8377456C_00_Charles Tan  1234567     A  S8377456C  00
# 1    1234567_A_S5868811B_00_Brave Lau  1234567     A  S5868811B  00
# 2    1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
# 3    1234567_A_S1478175K_00_Keith Kin  1234567     A  S1478175K  00
#
#           Name      account_no
# 0  Charles Tan  [001-005162-8]
# 1    Brave Lau  [001-005162-8]
# 2    Apple Lim  [001-005162-8]
# 3    Keith Kin  [001-005162-8]

# %%
'''
create the column called set_{}
'''
for i in range(0, len(w)):
    w[i]['Set'] = "Set" + str(i+1)
    
type(w)
w
# Out:
# 0                           list_of_name Corp CIN G...
# 1                           list_of_name Corp CIN G...
# 2                             list_of_name Corp CIN...
# 3                            list_of_name Corp CIN ...
# 4                             list_of_name Corp CIN...
# 5                             list_of_name Corp CIN...
# dtype: object

# %%
# change the series to list()
ww = w.tolist()
ww
# Out:
# [                       list_of_name Corp CIN Group    ind CIN SFX       Name  \
#  0  1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00  Apple Lim
#
#                                            account_no   Set
#  0  [0003-001933-01-3, 0003-002011-02-1, 0003-0189...  Set1  ,
#                         list_of_name Corp CIN Group    ind CIN SFX       Name  \
#  0  1234567_A_S5868811B_00_Brave Lau  1234567     A  S5868811B  00  Brave Lau
#  1  1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00  Apple Lim
#
#          account_no   Set
#  0  [001-018760-01]  Set2
#  1  [001-018760-01]  Set2  ,
#                           list_of_name Corp CIN Group    ind CIN SFX  \
#  0  1234567_A_S8377456C_00_Charles Tan  1234567     A  S8377456C  00
#  1    1234567_A_S5868811B_00_Brave Lau  1234567     A  S5868811B  00
#  2    1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
#  3    1234567_A_S1478175K_00_Keith Kin  1234567     A  S1478175K  00
#
#            Name      account_no   Set
#  0  Charles Tan  [001-005162-8]  Set3
#  1    Brave Lau  [001-005162-8]  Set3
#  2    Apple Lim  [001-005162-8]  Set3
#  3    Keith Kin  [001-005162-8]  Set3  ,
#                          list_of_name Corp CIN Group    ind CIN SFX  \
#  0   1234567_D_S1478175K_00_Keith Kin  1234567     D  S1478175K  00
#  1  1234567_D_S1184805L_00_Lim Ah How  1234567     D  S1184805L  00
#  2     1234567_C_S7114220I_20_Ice Ice  1234567     C  S7114220I  20
#  3  1234567_C_S2349083k_20_Jelly Bean  1234567     C  S2349083k  20
#  4   1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
#
#           Name          account_no   Set
#  0   Keith Kin  [0001-003579-05-0]  Set4
#  1  Lim Ah How  [0001-003579-05-0]  Set4
#  2     Ice Ice  [0001-003579-05-0]  Set4
#  3  Jelly Bean  [0001-003579-05-0]  Set4
#  4   Apple Lim  [0001-003579-05-0]  Set4  ,
#                           list_of_name Corp CIN Group    ind CIN SFX  \
#  0  1234568_A_S8377456C_00_Charles Tan  1234568     A  S8377456C  00
#  1    1234568_A_S5868811B_00_Brave Lau  1234568     A  S5868811B  00
#  2    1234568_A_S4695746A_00_Apple Lim  1234568     A  S4695746A  00
#
#            Name      account_no   Set
#  0  Charles Tan  [001-026485-0]  Set5
#  1    Brave Lau  [001-026485-0]  Set5
#  2    Apple Lim  [001-026485-0]  Set5  ,
#                           list_of_name Corp CIN Group    ind CIN SFX  \
#  0    1234569_B_S5868811B_00_Brave Lau  1234569     B  S5868811B  00
#  1    1234569_B_S4695746A_00_Apple Lim  1234569     B  S4695746A  00
#  2  1234567_A_S8377456C_00_Charles Tan  1234567     A  S8377456C  00
#
#            Name      account_no   Set
#  0    Brave Lau  [001-033965-5]  Set6
#  1    Apple Lim  [001-033965-5]  Set6
#  2  Charles Tan  [001-033965-5]  Set6  ]

# %%
# concat list of dataframes
q = pd.concat(ww)
q
# Out:
#                          list_of_name Corp CIN Group    ind CIN SFX  \
# 0    1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
# 0    1234567_A_S5868811B_00_Brave Lau  1234567     A  S5868811B  00
# 1    1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
# 0  1234567_A_S8377456C_00_Charles Tan  1234567     A  S8377456C  00
# 1    1234567_A_S5868811B_00_Brave Lau  1234567     A  S5868811B  00
# 2    1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
# 3    1234567_A_S1478175K_00_Keith Kin  1234567     A  S1478175K  00
# 0    1234567_D_S1478175K_00_Keith Kin  1234567     D  S1478175K  00
# 1   1234567_D_S1184805L_00_Lim Ah How  1234567     D  S1184805L  00
# 2      1234567_C_S7114220I_20_Ice Ice  1234567     C  S7114220I  20
# 3   1234567_C_S2349083k_20_Jelly Bean  1234567     C  S2349083k  20
# 4    1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
# 0  1234568_A_S8377456C_00_Charles Tan  1234568     A  S8377456C  00
# 1    1234568_A_S5868811B_00_Brave Lau  1234568     A  S5868811B  00
# 2    1234568_A_S4695746A_00_Apple Lim  1234568     A  S4695746A  00
# 0    1234569_B_S5868811B_00_Brave Lau  1234569     B  S5868811B  00
# 1    1234569_B_S4695746A_00_Apple Lim  1234569     B  S4695746A  00
# 2  1234567_A_S8377456C_00_Charles Tan  1234567     A  S8377456C  00
#
#           Name                                         account_no   Set
# 0    Apple Lim  [0003-001933-01-3, 0003-002011-02-1, 0003-0189...  Set1
# 0    Brave Lau                                    [001-018760-01]  Set2
# 1    Apple Lim                                    [001-018760-01]  Set2
# 0  Charles Tan                                     [001-005162-8]  Set3
# 1    Brave Lau                                     [001-005162-8]  Set3
# 2    Apple Lim                                     [001-005162-8]  Set3
# 3    Keith Kin                                     [001-005162-8]  Set3
# 0    Keith Kin                                 [0001-003579-05-0]  Set4
# 1   Lim Ah How                                 [0001-003579-05-0]  Set4
# 2      Ice Ice                                 [0001-003579-05-0]  Set4
# 3   Jelly Bean                                 [0001-003579-05-0]  Set4
# 4    Apple Lim                                 [0001-003579-05-0]  Set4
# 0  Charles Tan                                     [001-026485-0]  Set5
# 1    Brave Lau                                     [001-026485-0]  Set5
# 2    Apple Lim                                     [001-026485-0]  Set5
# 0    Brave Lau                                     [001-033965-5]  Set6
# 1    Apple Lim                                     [001-033965-5]  Set6
# 2  Charles Tan                                     [001-033965-5]  Set6

# %%
# appended dataframe
q
# drop the column "list_of_name"
q1 = q.drop(columns= "list_of_name", axis = 1)
q1 = q1.reset_index() # remove the weird indexing
del q1['index']
q2 = q1.groupby(['Set','Group']).size()
q
# Out:
#                          list_of_name Corp CIN Group    ind CIN SFX  \
# 0    1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
# 0    1234567_A_S5868811B_00_Brave Lau  1234567     A  S5868811B  00
# 1    1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
# 0  1234567_A_S8377456C_00_Charles Tan  1234567     A  S8377456C  00
# 1    1234567_A_S5868811B_00_Brave Lau  1234567     A  S5868811B  00
# 2    1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
# 3    1234567_A_S1478175K_00_Keith Kin  1234567     A  S1478175K  00
# 0    1234567_D_S1478175K_00_Keith Kin  1234567     D  S1478175K  00
# 1   1234567_D_S1184805L_00_Lim Ah How  1234567     D  S1184805L  00
# 2      1234567_C_S7114220I_20_Ice Ice  1234567     C  S7114220I  20
# 3   1234567_C_S2349083k_20_Jelly Bean  1234567     C  S2349083k  20
# 4    1234567_A_S4695746A_00_Apple Lim  1234567     A  S4695746A  00
# 0  1234568_A_S8377456C_00_Charles Tan  1234568     A  S8377456C  00
# 1    1234568_A_S5868811B_00_Brave Lau  1234568     A  S5868811B  00
# 2    1234568_A_S4695746A_00_Apple Lim  1234568     A  S4695746A  00
# 0    1234569_B_S5868811B_00_Brave Lau  1234569     B  S5868811B  00
# 1    1234569_B_S4695746A_00_Apple Lim  1234569     B  S4695746A  00
# 2  1234567_A_S8377456C_00_Charles Tan  1234567     A  S8377456C  00
#
#           Name                                         account_no   Set
# 0    Apple Lim  [0003-001933-01-3, 0003-002011-02-1, 0003-0189...  Set1
# 0    Brave Lau                                    [001-018760-01]  Set2
# 1    Apple Lim                                    [001-018760-01]  Set2
# 0  Charles Tan                                     [001-005162-8]  Set3
# 1    Brave Lau                                     [001-005162-8]  Set3
# 2    Apple Lim                                     [001-005162-8]  Set3
# 3    Keith Kin                                     [001-005162-8]  Set3
# 0    Keith Kin                                 [0001-003579-05-0]  Set4
# 1   Lim Ah How                                 [0001-003579-05-0]  Set4
# 2      Ice Ice                                 [0001-003579-05-0]  Set4
# 3   Jelly Bean                                 [0001-003579-05-0]  Set4
# 4    Apple Lim                                 [0001-003579-05-0]  Set4
# 0  Charles Tan                                     [001-026485-0]  Set5
# 1    Brave Lau                                     [001-026485-0]  Set5
# 2    Apple Lim                                     [001-026485-0]  Set5
# 0    Brave Lau                                     [001-033965-5]  Set6
# 1    Apple Lim                                     [001-033965-5]  Set6
# 2  Charles Tan                                     [001-033965-5]  Set6

# %%
'''
Save the table as well as the count of each "Group" in separate sheets in the same xlsx file
'''
filename = 'task1n2_PL_R2_v2.xlsx'
writer = pd.ExcelWriter(filename)

# write to csv the output
q1.to_excel(writer,sheet_name = "Task2_Table")

# new column ; add a column of Groups as shown in tha sample
uniquesets = q1.Set.unique()
print(uniquesets)
q2 = q1.groupby(['Set','Group']).size()
q2.to_excel(writer,sheet_name = 'Groups')
writer.save()
# Out:
# ['Set1' 'Set2' 'Set3' 'Set4' 'Set5' 'Set6']

# %% [markdown]
# # After run task 2 will run task 1

# %%
import pandas as pd
import itertools
# take only the account numbers left from task 2 to do task 1. Account number is the common key between both the datasets 
# SIG and ACC
listOfAccNumLeft = q.account_no.tolist()
listLeft = list(set(list(itertools.chain(*listOfAccNumLeft))))
print(listLeft)
# Out:
# ['0001-003579-05-0', '0003-020908-01-6', '001-005162-8', '001-026485-0', '0118-000200-01-8', '001-033965-5', '0003-001933-01-3', '0003-018997-03-6', '0003-002011-02-1', '001-018760-01']

# %%
# call out the df we need to use
dfADA = pd.read_excel(fn, sheetname = "ACC", converters = {'SI':str,'Corp CIN':str})
dfTask2 =  pd.read_excel('task1n2_PL_R2_v2.xlsx',sheetname = "Task2_Table",converters = {'SI':str})

#type(dfTask2.account_no[0])
# dfADA['Account no'] = dfADA['Account no'].str.strip()
dfADA = dfADA[dfADA['Account no'].isin(listLeft)]
print(dfTask2['account_no'])

dfADA['SI'] = dfADA['SI'].astype(str)
dfADA
# Out:
# 0     ['0003-001933-01-3', '0003-002011-02-1', '0003...
# 1                                     ['001-018760-01']
# 2                                     ['001-018760-01']
# 3                                      ['001-005162-8']
# 4                                      ['001-005162-8']
# 5                                      ['001-005162-8']
# 6                                      ['001-005162-8']
# 7                                  ['0001-003579-05-0']
# 8                                  ['0001-003579-05-0']
# 9                                  ['0001-003579-05-0']
# 10                                 ['0001-003579-05-0']
# 11                                 ['0001-003579-05-0']
# 12                                     ['001-026485-0']
# 13                                     ['001-026485-0']
# 14                                     ['001-026485-0']
# 15                                     ['001-033965-5']
# 16                                     ['001-033965-5']
# 17                                     ['001-033965-5']
# Name: account_no, dtype: object
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
#    Corp CIN        Account no  Type                           SI  \
# 0   1234567  0118-000200-01-8    20  AMT<=US$80K:FAC SIGS of Wee
# 1   1234567  0001-003579-05-0    20        Please refer to FCCA
# 2   1234567  0001-003579-05-0    20         AMT<= $150K/EQV:ANY2
# 3   1234567  0001-003579-05-0    20         AMT<= $150K/EQV:ANY2
# 4   1234567  0001-003579-05-0    20         AMT<= $150K/EQV:ANY2
# 5   1234567  0003-001933-01-3    20        Please refer to FCCA
# 6   1234567  0003-002011-02-1    20        Please refer to FCCA
# 7   1234567  0003-018997-03-6    20       Accept CHQS,CO,drafts&
# 8   1234567  0003-020908-01-6    20        Made payable to Bank,
# 9   1234567  0118-000200-01-8    20                      Vickers
# 10  1234567     001-018760-01    20  AMT<=US$80K:FAC SIGS of Wee
# 11  1234567     001-018760-01    20        Please refer to FCCA
# 12  1234568      001-026485-0    22        Please refer to FCCA
# 13  1234568      001-026485-0    22       Accept CHQS,CO,drafts&
# 14  1234568      001-026485-0    22        Made payable to Bank,
# 15  1234569      001-033965-5    22                      Vickers
# 16  1234569      001-033965-5    22        Please refer to FCCA
# 17  1234569      001-033965-5    22        Please refer to FCCA
#
#                               SR
# 0            Accept CHQS & Debit
# 1            Accept CHQS & Debit
# 2            Accept CHQS & Debit
# 3                            NaN
# 4            Accept CHQS & Debit
# 5                Pay to Account;
# 6                Pay to Account;
# 7                Pay to Account;
# 8                Pay to Account;
# 9                Pay to Account;
# 10                           NaN
# 11               Pay to Account;
# 12  Deposit Cheque, Vickers Sec;
# 13  Deposit Cheque, Vickers Sec;
# 14  Deposit Cheque, Vickers Sec;
# 15  Deposit Cheque, Vickers Sec;
# 16  Deposit Cheque, Vickers Sec;
# 17  Deposit Cheque, Vickers Sec;

# %%
'''
replacing na valyes in column "SR" with " " # the real data has some empty rows
'''
dfADA['SR'].fillna("", inplace = True)  # use " " or "" will also show empty.
dfADA
# Out:
#    Corp CIN        Account no  Type                           SI  \
# 0   1234567  0118-000200-01-8    20  AMT<=US$80K:FAC SIGS of Wee
# 1   1234567  0001-003579-05-0    20        Please refer to FCCA
# 2   1234567  0001-003579-05-0    20         AMT<= $150K/EQV:ANY2
# 3   1234567  0001-003579-05-0    20         AMT<= $150K/EQV:ANY2
# 4   1234567  0001-003579-05-0    20         AMT<= $150K/EQV:ANY2
# 5   1234567  0003-001933-01-3    20        Please refer to FCCA
# 6   1234567  0003-002011-02-1    20        Please refer to FCCA
# 7   1234567  0003-018997-03-6    20       Accept CHQS,CO,drafts&
# 8   1234567  0003-020908-01-6    20        Made payable to Bank,
# 9   1234567  0118-000200-01-8    20                      Vickers
# 10  1234567     001-018760-01    20  AMT<=US$80K:FAC SIGS of Wee
# 11  1234567     001-018760-01    20        Please refer to FCCA
# 12  1234568      001-026485-0    22        Please refer to FCCA
# 13  1234568      001-026485-0    22       Accept CHQS,CO,drafts&
# 14  1234568      001-026485-0    22        Made payable to Bank,
# 15  1234569      001-033965-5    22                      Vickers
# 16  1234569      001-033965-5    22        Please refer to FCCA
# 17  1234569      001-033965-5    22        Please refer to FCCA
#
#                               SR
# 0            Accept CHQS & Debit
# 1            Accept CHQS & Debit
# 2            Accept CHQS & Debit
# 3
# 4            Accept CHQS & Debit
# 5                Pay to Account;
# 6                Pay to Account;
# 7                Pay to Account;
# 8                Pay to Account;
# 9                Pay to Account;
# 10
# 11               Pay to Account;
# 12  Deposit Cheque, Vickers Sec;
# 13  Deposit Cheque, Vickers Sec;
# 14  Deposit Cheque, Vickers Sec;
# 15  Deposit Cheque, Vickers Sec;
# 16  Deposit Cheque, Vickers Sec;
# 17  Deposit Cheque, Vickers Sec;

# %%
'''
change order of columns in dataframe, Acc Number put infront
'''
dfAccNum = dfADA['Account no'].unique()
dfAccNum
dfAccNum_list = dfAccNum.tolist()
print("List of account numbers unique: {}".format(dfAccNum_list))
type(dfAccNum_list[0])
# Out:
# List of account numbers unique: ['0118-000200-01-8', '0001-003579-05-0', '0003-001933-01-3', '0003-002011-02-1', '0003-018997-03-6', '0003-020908-01-6', '001-018760-01', '001-026485-0', '001-033965-5']
# str

# %%
'''
reorder the columns in the df before i do a join "_" on dfADA
'''
new_order = [1,0,2,3,4]
dfADA = dfADA[dfADA.columns[new_order]]
dfADA = dfADA.drop(columns = "Corp CIN", axis = 1)
print(dfADA.head())
# Out:
#          Account no  Type                           SI                   SR
# 0  0118-000200-01-8    20  AMT<=US$80K:FAC SIGS of Wee  Accept CHQS & Debit
# 1  0001-003579-05-0    20        Please refer to FCCA   Accept CHQS & Debit
# 2  0001-003579-05-0    20         AMT<= $150K/EQV:ANY2  Accept CHQS & Debit
# 3  0001-003579-05-0    20         AMT<= $150K/EQV:ANY2
# 4  0001-003579-05-0    20         AMT<= $150K/EQV:ANY2  Accept CHQS & Debit

# %%
'''
Call out the account number and set number from Task 2
first list in task 2 is has a label "1" to all its elements corresponding to first list in the task 2 acc number and so on
'''
import re

setNum = dfTask2.Set
accNumTask2 = dfTask2.account_no.unique()

print(accNumTask2)
outputList = []
regStr = '[\\d-]+'
indexList = []
indexnum = 1
for outerLoop in accNumTask2:
    listofAccNum = re.findall(regStr , outerLoop)
    for accNum in listofAccNum:
        indexList.append(indexnum)
        outputList.append(accNum)
    indexnum = indexnum + 1
len(indexList)
len(outputList)

# One column is set num, 2nd column is account number
d = {'indexnum': indexList, 'accNum':outputList}
dfindexofInnerList = pd.DataFrame(data=d)
dfindexofInnerList
# Out:
# ["['0003-001933-01-3', '0003-002011-02-1', '0003-018997-03-6', '0003-020908-01-6', '0118-000200-01-8']"
#  "['001-018760-01']" "['001-005162-8']" "['0001-003579-05-0']"
#  "['001-026485-0']" "['001-033965-5']"]
#    indexnum            accNum
# 0         1  0003-001933-01-3
# 1         1  0003-002011-02-1
# 2         1  0003-018997-03-6
# 3         1  0003-020908-01-6
# 4         1  0118-000200-01-8
# 5         2     001-018760-01
# 6         3      001-005162-8
# 7         4  0001-003579-05-0
# 8         5      001-026485-0
# 9         6      001-033965-5

# %%
'''
Join all the columns separated by '_'
'''
dfADA_str = dfADA.astype(str)
dfADA_str['joined'] = dfADA_str.apply('_'.join, axis =1)
dfADA_str.head()
# Out:
#          Account no Type                           SI                   SR  \
# 0  0118-000200-01-8   20  AMT<=US$80K:FAC SIGS of Wee  Accept CHQS & Debit
# 1  0001-003579-05-0   20        Please refer to FCCA   Accept CHQS & Debit
# 2  0001-003579-05-0   20         AMT<= $150K/EQV:ANY2  Accept CHQS & Debit
# 3  0001-003579-05-0   20         AMT<= $150K/EQV:ANY2
# 4  0001-003579-05-0   20         AMT<= $150K/EQV:ANY2  Accept CHQS & Debit
#
#                                               joined
# 0  0118-000200-01-8_20_AMT<=US$80K:FAC SIGS of We...
# 1  0001-003579-05-0_20_Please refer to FCCA _Acce...
# 2  0001-003579-05-0_20_AMT<= $150K/EQV:ANY2_Accep...
# 3          0001-003579-05-0_20_AMT<= $150K/EQV:ANY2_
# 4  0001-003579-05-0_20_AMT<= $150K/EQV:ANY2_Accep...

# %%
'''
Split away the Account no from the joined column as it is supposed to be key-like. Same reason as in Task 2 above
'''
split_list = []
for string in dfADA_str.joined:
    split_Acc = string.split("_",1)
    split_list.append(split_Acc)

# %%
'''
convert the list of list back to a pandas dataframe for easier reading and handling
'''
import pandas as pd
df = pd.DataFrame(split_list, columns = ['Acc Num','joined'])
df.head()
# Out:
#             Acc Num                                             joined
# 0  0118-000200-01-8  20_AMT<=US$80K:FAC SIGS of Wee_Accept CHQS & D...
# 1  0001-003579-05-0       20_Please refer to FCCA _Accept CHQS & Debit
# 2  0001-003579-05-0        20_AMT<= $150K/EQV:ANY2_Accept CHQS & Debit
# 3  0001-003579-05-0                           20_AMT<= $150K/EQV:ANY2_
# 4  0001-003579-05-0        20_AMT<= $150K/EQV:ANY2_Accept CHQS & Debit

# %%
'''
Sort each list (in each row by ascending order so when we join the Dataframe the long string of rows in dataframe is ordered)
The ultimate aim is a dataframe for each group of account numbers.
To compare if the dataframes are the same, need to append all the rows of each dataframe that belongs to each account number 
into one long string

In order for the strings to be correctly matched, we need to sort the rows first before join
'''
dfsort = df.sort_values('joined',ascending = False)
dfsort
# Out:
#              Acc Num                                             joined
# 15      001-033965-5            22_Vickers_Deposit Cheque, Vickers Sec;
# 17      001-033965-5  22_Please refer to FCCA _Deposit Cheque, Vicke...
# 12      001-026485-0  22_Please refer to FCCA _Deposit Cheque, Vicke...
# 16      001-033965-5  22_Please refer to FCCA _Deposit Cheque, Vicke...
# 14      001-026485-0  22_Made payable to Bank,_Deposit Cheque, Vicke...
# 13      001-026485-0  22_Accept CHQS,CO,drafts&_Deposit Cheque, Vick...
# 9   0118-000200-01-8                         20_Vickers_Pay to Account;
# 11     001-018760-01           20_Please refer to FCCA _Pay to Account;
# 6   0003-002011-02-1           20_Please refer to FCCA _Pay to Account;
# 5   0003-001933-01-3           20_Please refer to FCCA _Pay to Account;
# 1   0001-003579-05-0       20_Please refer to FCCA _Accept CHQS & Debit
# 8   0003-020908-01-6           20_Made payable to Bank,_Pay to Account;
# 7   0003-018997-03-6          20_Accept CHQS,CO,drafts&_Pay to Account;
# 0   0118-000200-01-8  20_AMT<=US$80K:FAC SIGS of Wee_Accept CHQS & D...
# 10     001-018760-01                    20_AMT<=US$80K:FAC SIGS of Wee_
# 4   0001-003579-05-0        20_AMT<= $150K/EQV:ANY2_Accept CHQS & Debit
# 2   0001-003579-05-0        20_AMT<= $150K/EQV:ANY2_Accept CHQS & Debit
# 3   0001-003579-05-0                           20_AMT<= $150K/EQV:ANY2_

# %%
# making Acc Num the key and show list of "joined" under this key
# https://stackoverflow.com/questions/22219004/grouping-rows-in-list-in-pandas-groupby
dfgrouped = dfsort.groupby('Acc Num')['joined'].apply(list)
type(dfgrouped)
dfgrouped1 = pd.DataFrame(dfgrouped, columns = ['joined'])
print(dfgrouped1.head())
# Out:
#                                                              joined
# Acc Num
# 0001-003579-05-0  [20_Please refer to FCCA _Accept CHQS & Debit,...
# 0003-001933-01-3         [20_Please refer to FCCA _Pay to Account;]
# 0003-002011-02-1         [20_Please refer to FCCA _Pay to Account;]
# 0003-018997-03-6        [20_Accept CHQS,CO,drafts&_Pay to Account;]
# 0003-020908-01-6         [20_Made payable to Bank,_Pay to Account;]

# %%
'''
To check if a dataframe is the same across a few accounts, we need to join all the rows in the dataframe (of "ACC" sheet)
then check across all the accounts
'''
appendlist = []
for item in dfgrouped:
    a = " ".join(item)
    appendlist.append(a)
type(appendlist)

dfgrouped1 = dfgrouped1.assign(joinedlistToAcc = appendlist) # make a column of list to a column of string
dfgrouped1
# Out:
#                                                              joined  \
# Acc Num
# 0001-003579-05-0  [20_Please refer to FCCA _Accept CHQS & Debit,...
# 0003-001933-01-3         [20_Please refer to FCCA _Pay to Account;]
# 0003-002011-02-1         [20_Please refer to FCCA _Pay to Account;]
# 0003-018997-03-6        [20_Accept CHQS,CO,drafts&_Pay to Account;]
# 0003-020908-01-6         [20_Made payable to Bank,_Pay to Account;]
# 001-018760-01     [20_Please refer to FCCA _Pay to Account;, 20_...
# 001-026485-0      [22_Please refer to FCCA _Deposit Cheque, Vick...
# 001-033965-5      [22_Vickers_Deposit Cheque, Vickers Sec;, 22_P...
# 0118-000200-01-8  [20_Vickers_Pay to Account;, 20_AMT<=US$80K:FA...
#
#                                                     joinedlistToAcc
# Acc Num
# 0001-003579-05-0  20_Please refer to FCCA _Accept CHQS & Debit 2...
# 0003-001933-01-3           20_Please refer to FCCA _Pay to Account;
# 0003-002011-02-1           20_Please refer to FCCA _Pay to Account;
# 0003-018997-03-6          20_Accept CHQS,CO,drafts&_Pay to Account;
# 0003-020908-01-6           20_Made payable to Bank,_Pay to Account;
# 001-018760-01     20_Please refer to FCCA _Pay to Account; 20_AM...
# 001-026485-0      22_Please refer to FCCA _Deposit Cheque, Vicke...
# 001-033965-5      22_Vickers_Deposit Cheque, Vickers Sec; 22_Ple...
# 0118-000200-01-8  20_Vickers_Pay to Account; 20_AMT<=US$80K:FAC ...

# %%
'''
 make a duplicate of the index column so it has a header name because index has no header name
'''
dfgrouped1['Acc'] = dfgrouped1.index

# %%
'''
According to the inspection on the previous output, we can see that the strings have spaces infront and behind the account numbers
and all the elements have different number of spaces. We now strip away the spaces
'''
acc= []
for row in dfgrouped1['Acc']:
    a = row.strip()
    acc.append(a)
    
dfgrouped1 = dfgrouped1.assign(Acc = acc)

# %%
'''
Merge 2 df by account number, so we can also add the column of set number to dfgrouped1
'''
dfgrouped1_1 = pd.merge(dfgrouped1, dfindexofInnerList, how = "left", left_on = ['Acc'], right_on = ['accNum'])
dfgrouped1_1
# Out:
#                                               joined  \
# 0  [20_Please refer to FCCA _Accept CHQS & Debit,...
# 1         [20_Please refer to FCCA _Pay to Account;]
# 2         [20_Please refer to FCCA _Pay to Account;]
# 3        [20_Accept CHQS,CO,drafts&_Pay to Account;]
# 4         [20_Made payable to Bank,_Pay to Account;]
# 5  [20_Please refer to FCCA _Pay to Account;, 20_...
# 6  [22_Please refer to FCCA _Deposit Cheque, Vick...
# 7  [22_Vickers_Deposit Cheque, Vickers Sec;, 22_P...
# 8  [20_Vickers_Pay to Account;, 20_AMT<=US$80K:FA...
#
#                                      joinedlistToAcc               Acc  \
# 0  20_Please refer to FCCA _Accept CHQS & Debit 2...  0001-003579-05-0
# 1           20_Please refer to FCCA _Pay to Account;  0003-001933-01-3
# 2           20_Please refer to FCCA _Pay to Account;  0003-002011-02-1
# 3          20_Accept CHQS,CO,drafts&_Pay to Account;  0003-018997-03-6
# 4           20_Made payable to Bank,_Pay to Account;  0003-020908-01-6
# 5  20_Please refer to FCCA _Pay to Account; 20_AM...     001-018760-01
# 6  22_Please refer to FCCA _Deposit Cheque, Vicke...      001-026485-0
# 7  22_Vickers_Deposit Cheque, Vickers Sec; 22_Ple...      001-033965-5
# 8  20_Vickers_Pay to Account; 20_AMT<=US$80K:FAC ...  0118-000200-01-8
#
#    indexnum            accNum
# 0         4  0001-003579-05-0
# 1         1  0003-001933-01-3
# 2         1  0003-002011-02-1
# 3         1  0003-018997-03-6
# 4         1  0003-020908-01-6
# 5         2     001-018760-01
# 6         5      001-026485-0
# 7         6      001-033965-5
# 8         1  0118-000200-01-8

# %%
'''
First merge the column of set number with account number as key

then group by this key, and we join all the elements "joinedlistToAcc" with "|" and "Acc" with "|"
'''
# group by indexnum which is set number, then aggregate list for both "acc" and "joined"
dfgrouped1_1['indexnum_acc'] = dfgrouped1_1['indexnum'].map(str) + "_" + dfgrouped1_1['Acc']
dfgrouped2 = dfgrouped1_1.groupby(['indexnum_acc'],
                                 as_index = False)['joinedlistToAcc','Acc'].agg('|'.join) #.agg(lambda x: list(x))
print(type(dfgrouped2))
dfgrouped2
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          indexnum_acc                                    joinedlistToAcc  \
# 0  1_0003-001933-01-3           20_Please refer to FCCA _Pay to Account;
# 1  1_0003-002011-02-1           20_Please refer to FCCA _Pay to Account;
# 2  1_0003-018997-03-6          20_Accept CHQS,CO,drafts&_Pay to Account;
# 3  1_0003-020908-01-6           20_Made payable to Bank,_Pay to Account;
# 4  1_0118-000200-01-8  20_Vickers_Pay to Account; 20_AMT<=US$80K:FAC ...
# 5     2_001-018760-01  20_Please refer to FCCA _Pay to Account; 20_AM...
# 6  4_0001-003579-05-0  20_Please refer to FCCA _Accept CHQS & Debit 2...
# 7      5_001-026485-0  22_Please refer to FCCA _Deposit Cheque, Vicke...
# 8      6_001-033965-5  22_Vickers_Deposit Cheque, Vickers Sec; 22_Ple...
#
#                 Acc
# 0  0003-001933-01-3
# 1  0003-002011-02-1
# 2  0003-018997-03-6
# 3  0003-020908-01-6
# 4  0118-000200-01-8
# 5     001-018760-01
# 6  0001-003579-05-0
# 7      001-026485-0
# 8      001-033965-5

# %%
'''
As there are many "," inside the column of joinedlistToAcc
we need to separate each entry into each row
other rows are replicated across the added rows
'''
# step 1 : start with creating a new dataframe from the series 
d = {'joinedlistToAcc': dfgrouped2.joinedlistToAcc.str.split('|').tolist()}
new_df = pd.DataFrame(data = d , index = dfgrouped2.indexnum_acc).stack()
# step 2: we now want to get rid of the secondary index
new_df =  new_df.reset_index([0, 'indexnum_acc'])
#step 3: the final step is to set the column names as we want them
new_df.columns = ['indexnum_acc','Acc']
new_df
# Out:
#          indexnum_acc                                                Acc
# 0  1_0003-001933-01-3         [20_Please refer to FCCA _Pay to Account;]
# 1  1_0003-002011-02-1         [20_Please refer to FCCA _Pay to Account;]
# 2  1_0003-018997-03-6        [20_Accept CHQS,CO,drafts&_Pay to Account;]
# 3  1_0003-020908-01-6         [20_Made payable to Bank,_Pay to Account;]
# 4  1_0118-000200-01-8  [20_Vickers_Pay to Account; 20_AMT<=US$80K:FAC...
# 5     2_001-018760-01  [20_Please refer to FCCA _Pay to Account; 20_A...
# 6  4_0001-003579-05-0  [20_Please refer to FCCA _Accept CHQS & Debit ...
# 7      5_001-026485-0  [22_Please refer to FCCA _Deposit Cheque, Vick...
# 8      6_001-033965-5  [22_Vickers_Deposit Cheque, Vickers Sec; 22_Pl...

# %%
# create many dataframes based on each Set number
def my_function(row):
    # row is df
    # initialise a dataframe
    df = pd.DataFrame({'list_of_names':row['joinedlistToAcc'],
                      'indexnum_acc':row['indexnum_acc']}, index = [0]) # start the index with 0
    new1 = df['indexnum_acc'].str.split("_", n=1, expand=True)
    df['Set Num'] = new1[0]
    df['Account_no'] = new1[1]
    new = df['list_of_names'].str.split("_", n=2, expand = True)
    df['Type'] = new[0]
    df['SI'] = new[1]
    df['SR'] = new[2]
    
    return df

# %%
# apply on dataframe dfgrouped2
dfgrouped3 = dfgrouped2.apply(my_function, axis =1)
print(type(dfgrouped3))
dfgrouped3
# Out:
# <class 'pandas.core.series.Series'>
# 0                                  list_of_names   ...
# 1                                  list_of_names   ...
# 2                                   list_of_names  ...
# 3                                  list_of_names   ...
# 4                                           list_of...
# 5                                           list_of...
# 6                                           list_of...
# 7                                           list_of...
# 8                                           list_of...
# dtype: object

# %%
# change pandas series to list()
ww = dfgrouped3.tolist()

# %%
# concat list of dataframes
q = pd.concat(ww)
q
# Out:
#                                        list_of_names        indexnum_acc  \
# 0           20_Please refer to FCCA _Pay to Account;  1_0003-001933-01-3
# 0           20_Please refer to FCCA _Pay to Account;  1_0003-002011-02-1
# 0          20_Accept CHQS,CO,drafts&_Pay to Account;  1_0003-018997-03-6
# 0           20_Made payable to Bank,_Pay to Account;  1_0003-020908-01-6
# 0  20_Vickers_Pay to Account; 20_AMT<=US$80K:FAC ...  1_0118-000200-01-8
# 0  20_Please refer to FCCA _Pay to Account; 20_AM...     2_001-018760-01
# 0  20_Please refer to FCCA _Accept CHQS & Debit 2...  4_0001-003579-05-0
# 0  22_Please refer to FCCA _Deposit Cheque, Vicke...      5_001-026485-0
# 0  22_Vickers_Deposit Cheque, Vickers Sec; 22_Ple...      6_001-033965-5
#
#   Set Num        Account_no Type                      SI  \
# 0       1  0003-001933-01-3   20   Please refer to FCCA
# 0       1  0003-002011-02-1   20   Please refer to FCCA
# 0       1  0003-018997-03-6   20  Accept CHQS,CO,drafts&
# 0       1  0003-020908-01-6   20   Made payable to Bank,
# 0       1  0118-000200-01-8   20                 Vickers
# 0       2     001-018760-01   20   Please refer to FCCA
# 0       4  0001-003579-05-0   20   Please refer to FCCA
# 0       5      001-026485-0   22   Please refer to FCCA
# 0       6      001-033965-5   22                 Vickers
#
#                                                   SR
# 0                                    Pay to Account;
# 0                                    Pay to Account;
# 0                                    Pay to Account;
# 0                                    Pay to Account;
# 0  Pay to Account; 20_AMT<=US$80K:FAC SIGS of Wee...
# 0    Pay to Account; 20_AMT<=US$80K:FAC SIGS of Wee_
# 0  Accept CHQS & Debit 20_AMT<= $150K/EQV:ANY2_Ac...
# 0  Deposit Cheque, Vickers Sec; 22_Made payable t...
# 0  Deposit Cheque, Vickers Sec; 22_Please refer t...

# %%
# drop uneeded columns
q3 = q.drop(columns = ['list_of_names','indexnum_acc'])
q3
# Out:
#   Set Num        Account_no Type                      SI  \
# 0       1  0003-001933-01-3   20   Please refer to FCCA
# 0       1  0003-002011-02-1   20   Please refer to FCCA
# 0       1  0003-018997-03-6   20  Accept CHQS,CO,drafts&
# 0       1  0003-020908-01-6   20   Made payable to Bank,
# 0       1  0118-000200-01-8   20                 Vickers
# 0       2     001-018760-01   20   Please refer to FCCA
# 0       4  0001-003579-05-0   20   Please refer to FCCA
# 0       5      001-026485-0   22   Please refer to FCCA
# 0       6      001-033965-5   22                 Vickers
#
#                                                   SR
# 0                                    Pay to Account;
# 0                                    Pay to Account;
# 0                                    Pay to Account;
# 0                                    Pay to Account;
# 0  Pay to Account; 20_AMT<=US$80K:FAC SIGS of Wee...
# 0    Pay to Account; 20_AMT<=US$80K:FAC SIGS of Wee_
# 0  Accept CHQS & Debit 20_AMT<= $150K/EQV:ANY2_Ac...
# 0  Deposit Cheque, Vickers Sec; 22_Made payable t...
# 0  Deposit Cheque, Vickers Sec; 22_Please refer t...

# %%
'''
save the output to the dataframe we saved earlier 'task1n2_PL_R2_v2.xlsx', and add a new sheet to that dataframe called 'Task1_Table'
'''
from openpyxl import load_workbook
book = load_workbook(filename)
writer = pd.ExcelWriter(filename,engine = 'openpyxl')
writer.book = book
q3.to_excel(writer ,sheet_name ='Task1_Table')
writer.save()
